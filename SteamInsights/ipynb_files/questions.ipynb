# %%
# # Questions:

'''
Answered in Functions in summary.py or analysis_functions.py

what is the average price of an action game? adventure game?
    summary_stats_by_tag(chosen_tag, drop_zeroes=True)
    graph_mean_tag_prices(which='common', num=10, drop_zeroes=True)
    
look at what tags are commonly used together?
    tags_related()
    tags_related_plot()
    
summary function for developers and publishers
    company_summary('Rockstar Games', False)


how closely related are the metacritic_score and user_score?
    use analyze function

which producers/developers have the highest priced games, highest reviewed, most sales?
    hard to answer in one function...
        could make a producer/developer score for number of positively rated games / # of games by them
    top_n_values(df, column='developers', criteria='price', top_n=5, plot=False)
    
do single player games sell more than multiplayer games? rate better?
    analyze (players VS sales or sentiment)
        
# Don't have a function yet:




what is the average number of achievements for nonzero games?
    a really simple question...
    
Regression --> might be harder than we think just because we would have to do a bunch of transformations/
changes to the categorical variables (to encode them), not a great dataset for regression actually



I'm not sure yet how to import the functions from the summary.py and analysis_functions.py yet...
'''

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from analytic_functions import *
from summary import *

all_games = pd.read_csv('data/all_games_cleaned.csv')
# all_games.dtypes

tags = pd.read_csv('data/tags.csv')

# %%
# which producers/developers have the highest priced games, highest reviewed, most sales?
# use the analyze and graph functions here...
top_n_values(all_games, column='developers', criteria='global_sales', top_n=6, plot=True)
# Out:
#                                           developers  global_sales
# 0                                     Rockstar North     29.705000
# 1                                     Rockstar Games     18.363333
# 2                                           Treyarch     15.830000
# 3                              Bethesda Game Studios     11.500000
# 4                                        Core Design      7.530000
# 5  Ubisoft Montreal, Massive Entertainment, and U...      7.320000

# %%
# do single player games sell more than multiplayer games? rate better?
analysis_results = analyze_single_vs_multiplayer(all_games)
print(analysis_results)
analyze_single_vs_multiplayer()
# Out:
#         Category  Average Sales  Average Sentiment
# 0  Single Player       1.026436          77.465632
# 1    Multiplayer       0.391538          69.076923

# %%
# what is the average price of an action game? adventure game? (not including free ones)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490 entries, 0 to 489
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   appid                       490 non-null    int64
#  1   name                        490 non-null    object
#  2   estimated_owners            490 non-null    float64
#  3   price                       490 non-null    float64
#  4   dlc_count                   490 non-null    int64
#  5   windows                     490 non-null    bool
#  6   mac                         490 non-null    bool
#  7   linux                       490 non-null    bool
#  8   metacritic_score            490 non-null    int64
#  9   user_score                  490 non-null    int64
#  10  achievements                490 non-null    int64
#  11  recommendations             490 non-null    int64
#  12  average_playtime_forever    490 non-null    int64
# ...

# %%
# function to get the top 10 most common tags and get average price for each and plot?

graph_mean_tag_prices('least_exp', 20)

# %%
# corr = df['Variable1'].corr(df['Variable2'])
# look at what tags are commonly used together?
compare_two_tags('Action', 'Adventure')

# it would be too hard to check the number of joint occurrences between all pairs of tags - too many?
# Out:
# Correlation coefficient: 0.2252431257058595
# P-value: 4.7012745289452514e-07

# %%
result = tags_related(5)
print(result)
# Out:
# [(('Singleplayer', 'Action'), 264), (('Singleplayer', 'Adventure'), 227), (('Action', 'Adventure'), 199), (('Singleplayer', 'Multiplayer'), 177), (('Action', 'Multiplayer'), 145), (('Adventure', 'Multiplayer'), 95)]

# %%
tags_related(5, True)
# Out:
# /var/folders/xb/kh9kw84n5k57h6w4jp5kr23m0000gn/T/ipykernel_87005/394665713.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=[f'{pair[0]}-{pair[1]}' for pair, count in result], y=[count for pair, count in result], palette='viridis')
